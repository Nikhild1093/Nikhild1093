# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhild1093/Nikhild1093/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 66.0M/66.0M [00:00<00:00, 134MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
data = pd.read_csv('/root/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
data.isnull().sum()

# %%
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
legit.describe()
# Out:
#                 Time             V1  ...         Amount     Class
# count  284315.000000  284315.000000  ...  284315.000000  284315.0
# mean    94838.202258       0.008258  ...      88.291022       0.0
# std     47484.015786       1.929814  ...     250.105092       0.0
# min         0.000000     -56.407510  ...       0.000000       0.0
# 25%     54230.000000      -0.917544  ...       5.650000       0.0
# 50%     84711.000000       0.020023  ...      22.000000       0.0
# 75%    139333.000000       1.316218  ...      77.050000       0.0
# max    172792.000000       2.454930  ...   25691.160000       0.0
#
# [8 rows x 31 columns]

# %%
fraud.describe()
# Out:
#                 Time          V1          V2  ...         V28       Amount  Class
# count     492.000000  492.000000  492.000000  ...  492.000000   492.000000  492.0
# mean    80746.806911   -4.771948    3.623778  ...    0.075667   122.211321    1.0
# std     47835.365138    6.783687    4.291216  ...    0.547291   256.683288    0.0
# min       406.000000  -30.552380   -8.402154  ...   -1.869290     0.000000    1.0
# 25%     41241.500000   -6.036063    1.188226  ...   -0.108868     1.000000    1.0
# 50%     75568.500000   -2.342497    2.717869  ...    0.146344     9.250000    1.0
# 75%    128483.000000   -0.419200    4.971257  ...    0.381152   105.890000    1.0
# max    170348.000000    2.132386   22.057729  ...    1.779364  2125.870000    1.0
#
# [8 rows x 31 columns]

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0      94838.202258  0.008258 -0.006271  ... -0.000295 -0.000131   88.291022
# 1      80746.806911 -4.771948  3.623778  ...  0.170575  0.075667  122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492,random_state=1)
new_data = pd.concat([legit_sample, fraud],axis=0)
new_data
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 106066   69808.0  0.136174 -1.647766  ...  0.138062  540.00      0
# 102005   68015.0 -0.911610  0.680815  ...  0.159864    6.89      0
# 278450  168231.0 -0.917299  0.860942  ...  0.115137   19.99      0
# 120218   75751.0  1.252596  0.021359  ...  0.002433   17.80      0
# 258527  158694.0 -1.109483  1.061341  ...  0.068794   24.48      0
# ...          ...       ...       ...  ...       ...     ...    ...
# 279863  169142.0 -1.927883  1.125653  ...  0.147968  390.00      1
# 280143  169347.0  1.378559  1.289381  ...  0.186637    0.76      1
# 280149  169351.0 -0.676143  1.126366  ...  0.194361   77.89      1
# 281144  169966.0 -3.113832  0.585864  ... -0.253700  245.00      1
# 281674  170348.0  1.991976  0.158476  ... -0.015309   42.53      1
#
# [984 rows x 31 columns]

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0      99659.808943  0.042711 -0.137314  ...  0.006523  0.026847  109.156341
# 1      80746.806911 -4.771948  3.623778  ...  0.170575  0.075667  122.211321
#
# [2 rows x 30 columns]

# %%
X = new_data.drop(['Time','Class'],axis=1)
Y = new_data['Class']

print(X)
print(Y)
# Out:
#               V1        V2        V3  ...       V27       V28  Amount
# 106066  0.136174 -1.647766  0.850033  ... -0.018220  0.138062  540.00
# 102005 -0.911610  0.680815  1.344329  ... -0.026174  0.159864    6.89
# 278450 -0.917299  0.860942  1.201170  ...  0.177416  0.115137   19.99
# 120218  1.252596  0.021359  0.044063  ... -0.029793  0.002433   17.80
# 258527 -1.109483  1.061341  1.484072  ...  0.209439  0.068794   24.48
# ...          ...       ...       ...  ...       ...       ...     ...
# 279863 -1.927883  1.125653 -4.518331  ...  0.292680  0.147968  390.00
# 280143  1.378559  1.289381 -5.004247  ...  0.389152  0.186637    0.76
# 280149 -0.676143  1.126366 -2.213700  ...  0.385107  0.194361   77.89
# 281144 -3.113832  0.585864 -5.399730  ...  0.884876 -0.253700  245.00
# 281674  1.991976  0.158476 -2.583441  ...  0.002988 -0.015309   42.53
#
# [984 rows x 29 columns]
# 106066    0
# 102005    0
# 278450    0
# 120218    0
# 258527    0
#          ..
# 279863    1
# ...

# %%
(XTrain, XTest, YTrain, YTest) = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=1)
model = LogisticRegression(max_iter=1000)

model.fit(XTrain, YTrain)
# Out:
# LogisticRegression(max_iter=1000)

# %%
xtrPredict = model.predict(XTrain)

xtrAccu = accuracy_score(xtrPredict,YTrain)
xtrAccu
# Out:
# 0.9555273189326556

# %%
xtstPredict = model.predict(XTest)

print(accuracy_score(xtstPredict,YTest))
print(precision_score(xtstPredict,YTest))
print(recall_score(xtstPredict,YTest))
print(f1_score(xtstPredict,YTest))
# Out:
# 0.949238578680203
# 0.898989898989899
# 1.0
# 0.9468085106382979
